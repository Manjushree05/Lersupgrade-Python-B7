# %%
#list and its defalut methods 
lst=[2,'hi',5,6,8,9,10]
lst.append("manju")
print(lst)
# Out:
# [2, 'hi', 5, 6, 8, 9, 10, 'manju']

# %%
lst=[3,4,'hello',5,10]
lst.insert(3,"papu")
print(lst)
# Out:
# [3, 4, 'hello', 'papu', 5, 10]

# %%
lst1=["fcs",78.6,4,"letsupgrade"]
lst2=[1,2,3,5,6]
lst1.extend(lst2)
lst2.extend(lst1)
print(lst1)
print(lst2)
# Out:
# ['fcs', 78.6, 4, 'letsupgrade', 1, 2, 3, 5, 6]
# [1, 2, 3, 5, 6, 'fcs', 78.6, 4, 'letsupgrade', 1, 2, 3, 5, 6]

# %%
l=[3,4,5,6,7,8,9]
print(sum(l))
# Out:
# 42

# %%
p=[3,4,"pavi","jai",5,6,"manju"]
print(p.count("manju"))
# Out:
# 2

# %%
list=[3,'hi',9,76,3,5,6,3]
print(len(list))
# Out:
# 8

# %%
list=[2,3,4,5,6,7,8,9,4]
print(list.index(6))
# Out:
# 4

# %%
list=[4,5,6,7,0.5]
print(min(list))
print(max(list))
# Out:
# 0.5
# 7

# %%
list=[3,4,8,10,1000,78,86]
sorted(list)
# Out:
# [3, 4, 8, 10, 78, 86, 1000]

# %%
list=[3,4,8,10,1000,78,86]
sorted(list)
# Out:
# [3, 4, 8, 10, 78, 86, 1000]

# %%
list=[5,7,10,45,56]
list.sort(reverse=True)
print(list)
# Out:
# [56, 45, 10, 7, 5]

# %%
list=[9,90,867,"manju"]
list.pop()
# Out:
# 'manju'

# %%
list=[90,3.45,67,8]
list.remove(90)
print(list)
# Out:
# [3.45, 67, 8]

# %%
list=[9,67,45,56,78]
list.clear()
print(list)
# Out:
# []

# %%
list=[78,6,5,4,3]
list.copy()
# Out:
# [78, 6, 5, 4, 3]

# %%
###DICTIONARY AND ITS DEFALUT FUNCTION
dict = {"brand": "Ford",
  "model": "Mustang",
  "year": 1964}
print(dict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
dict = {"brand": "Ford",
  "model": "Mustang",
  "year": 1964}
dict.clear()
print(dict)
# Out:
# {}

# %%
dict = {"brand": "Ford",
  "model": "Mustang",
  "year": 1964}
p=dict.copy()
print(p)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
dict = {"name": "manju",
  "place": "Banglore",
  "year": 1999}
v=dict.get("place")
print(v)
# Out:
# Banglore

# %%
x = ('key1', 'key2', 'key3')
y = "fcs"
p = dict.fromkeys(x, y)
print(p)
# Out:
# {'key1': 'fcs', 'key2': 'fcs', 'key3': 'fcs'}

# %%
dict = {"name": "manju",
  "place": "Banglore",
  "year": 1999}
c=dict.items()
dict["place"]='mangalore'
print(c)
# Out:
# dict_items([('name', 'manju'), ('place', 'mangalore'), ('year', 1999)])

# %%
dict = {"name": "manju",
  "place": "Banglore",
  "year": 1999}
v=dict.keys()
print(v)
# Out:
# dict_keys(['name', 'place', 'year'])

# %%
dict = {"name": "manju",
  "place": "Banglore",
  "year": 1999}
dict.pop("place")
print(dict)
# Out:
# {'name': 'manju', 'year': 1999}

# %%
dict = {"name": "manju",
  "place": "Banglore",
  "year": 1999}
v=dict.popitem()
print(v)
# Out:
# ('year', 1999)

# %%
dict = {"name": "manju",
  "place": "Banglore",
  "year": 1999}
v=dict.setdefault("place","pune")
print(v)
# Out:
# Banglore

# %%
car = {"brand": "Ford",
  "model": "Mustang",
  "year": 1964}
car.update({"color": "White"})
print(car)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'White'}

# %%
dict = {"name": "manju",
  "place": "Banglore",
  "year": 1999}
c=dict.values()
dict["place"]='mangalore'
print(c)
# Out:
# dict_values(['manju', 'mangalore', 1999])

# %%
##sets and its defalut methods
s={3,4,5,6,7,"hi"}
s.add("manju")
print(s)
# Out:
# {3, 4, 5, 6, 7, 'hi', 'manju'}

# %%
s={3,4,5,6,7,"hi"}
s.clear()
print(s)
# Out:
# set()

# %%
s={3,4,5,6,7,"hi"}
p =s.copy()
print(s)
# Out:
# {3, 4, 5, 6, 7, 'hi'}

# %%
s={3,4,5,6,7,"hi"}
p={5,6,7,8}
q=s.difference(p)
r=p.difference(s)
print(q)
print(r)
# Out:
# {'hi', 3, 4}
# {8}

# %%
s={3,4,5,6,7,"hi"}
p={5,6,7,8}
s.difference_update(p)
print(s)
# Out:
# {3, 4, 'hi'}

# %%
s={3,4,5,6,7,"hi"}
s.discard("hi")
print(s)
# Out:
# {3, 4, 5, 6, 7}

# %%
s={3,4,5,6,7,"hi"}
p={5,6,7,8}
r=p.intersection(s)
q=s.intersection(p)
print(r)
print(q)
# Out:
# {5, 6, 7}
# {5, 6, 7}

# %%
s={3,4,5,6,7,"hi"}
p={5,6,7,8}
s.intersection_update(p)
print(s)
# Out:
# {5, 6, 7}

# %%
s={3,4,5,6,7,"hi"}
p={9,'manju',2,8}
z=s.isdisjoint(p)
print(z)
# Out:
# True

# %%
s={3,4,5,6,7,"hi"}
p={5,6,7,8}
r=s.isdisjoint(p)
print(r)
# Out:
# False

# %%
s={3,4,5,6,7,"hi"}
p={5,6,7,8}
q=s.issubset(p)
print(q)
# Out:
# False

# %%
s={3,4,5,6,7,"hi",'e',7,8,9}
p={5,6,7,8}
w=p.issubset(s)
print(w)
# Out:
# True

# %%
s={3,4,5,6,7,"hi",'e',7,8,9}
p={5,6,7,8}
t=s.issuperset(p)
print(t)
# Out:
# True

# %%
s={3,4,5,6,7,"hi",'e',7,8,9}
p={5,6,7,8}
t=p.issuperset(s)
print(t)
# Out:
# False

# %%
s={3,4,5,6,7,"hi",'e',7,8,9}
s.pop()
# Out:
# 3

# %%
s={3,4,5,6,7,"hi",'e',7,8,9}
s.remove(5)
print(s)
# Out:
# {3, 4, 6, 7, 'hi', 'e', 8, 9}

# %%
s={3,4,5,6,7,"hi",'e',7,8,9}
p={5,6,7,8}
p.symmetric_difference(s)
print(p)
# Out:
# {8, 5, 6, 7}

# %%
s={3,4,5,6,7,"hi",'e',7,8,9}
p={5,6,7,8}
s.symmetric_difference(p)
print(s)
# Out:
# {3, 4, 5, 6, 7, 'hi', 'e', 8, 9}

# %%
s={3,4,5,6,7,"hi",'e',7,8,9}
p={5,6,7,8}
p.symmetric_difference_update(s)
print(p)
# Out:
# {3, 4, 'e', 'hi', 9}

# %%
s={4,5,6,7}
p={5,6,7,8}
s.symmetric_difference_update(p)
print(s)
# Out:
# {4, 8}

# %%
s={4,5,6,7}
p={5,6,7,8}
w=s.union(p)
print(w)
# Out:
# {4, 5, 6, 7, 8}

# %%
s={4,5,6,7}
p={5,6,7,8}
s.update(p)
print(s)
# Out:
# {4, 5, 6, 7, 8}

# %%
### Tuples and its default functions
tuple = (1, 3, 7, 8, 7, 5, 4, 7, 8, 5)
x = tuple.count(7)
print(x)
# Out:
# 3

# %%
tuple = (1, 3, 7, 8, 7, 5, 4, 6, 8, 5)
x = tuple.index(3)
print(x)
# Out:
# 1

# %%
##string and its default methods
p= "hi all i am the student of letsupgrade"
x = p.capitalize()
print (x)
# Out:
# Hi all i am the student of letsupgrade

# %%
p = "HI, My Place Is Banglore"
x = p.casefold()
print(x)
# Out:
# hi, my place is banglore

# %%
t = "manjushree"
x = t.center(9)
print(x)
# Out:
# manjushree

# %%
w = "I love python,i will learn python in letsupgrade"
x = w.count("python")
print(x)
# Out:
# 2

# %%
q= "My name is manjushree"
x = q.encode()
print(x)
# Out:
# b'My name is manjushree'

# %%
txt = "Hello,i am manju."
x = txt.endswith(".")
print(x)
# Out:
# True

# %%
txt = "Hello,i am manju."
x = txt.endswith("a")
print(x)
# Out:
# False

# %%
e= "m\ta\tn\tj\tu"
x =  e.expandtabs(4)
print(x)
# Out:
# m   a   n   j   u

# %%
e= "m\ta\tn\tj\tu"
x =  e.expandtabs(2)
print(x)
# Out:
# m a n j u

# %%
str= "Hello, welcome to letsupgrade."
x = str.index("welcome")
print(x)
# Out:
# 7

# %%
str= "Hello, welcome to letsupgrade."
x = str.index("letsupgrade")
print(x)
# Out:
# 18

# %%
txt = "Hello, welcome to my world."
x = txt.find("welcome")
print(x)
# Out:
# 7

# %%
str= "THIS IS NOW!"
x=str.isupper()
print(x)
# Out:
# True

# %%
str= "i will learn python"
x=str.islower()
print(x)
# Out:
# True
